# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['ribeira grande',
#  'souillac',
#  'surt',
#  'neftcala',
#  'jamestown',
#  'ushuaia',
#  'arraial do cabo',
#  'sala consilina',
#  'savannah bight',
#  'port alfred',
#  'cockburn town',
#  'cidreira',
#  'narsaq',
#  'la baule-escoublac',
#  'san cristobal',
#  'busselton',
#  'clyde river',
#  'lerwick',
#  'tanga',
#  'castro',
#  'tsihombe',
#  'cape town',
#  'belushya guba',
#  'vestmanna',
#  'keetmanshoop',
#  'rey bouba',
#  'lagoa',
#  'kruisfontein',
#  'santa vitoria do palmar',
#  'taolanaro',
#  'umzimvubu',
#  'ginda',
#  'quatre cocos',
#  'horadiz',
#  'kondinskoye',
#  'sambava',
#  'aleksandrov gay',
#  'east london',
#  'barentsburg',
#  'rochegda',
#  'tasiilaq',
#  'pagman',
#  'namibe',
#  'korla',
#  'nokaneng',
#  'bandarbeyla',
#  'chuy',
#  'ofaqim',
#  'cravo norte',
#  'narasannapeta',
#  'illoqqortoormiut',
#  'babanka',
#  'karkaralinsk',
#  'ohangaron',
#  'bredasdorp',
#  'gasa',
#  'san carlos de bariloche',
#  'nelidovo',
#  'maceio',
#  'urucara',
#  'pionerskiy',
#  'grand gaube',
#  'buchanan',
#  'cap malheureux',
#  'azare',
#  'lima',
#  'mezhdurechensk',
#  'saint-philippe',
#  'vestmannaeyjar',
#  'coihaique',
#  'sur',
#  'ostrovnoy',
#  'taoudenni',
#  'victoria',
#  'urdoma',
#  'barawe',
#  'bambous virieux',
#  'saint george',
#  'grand river south east',
#  'paamiut',
#  'shieli',
#  'san ramon de la nueva oran',
#  'iralaya',
#  'tumannyy',
#  'tara',
#  'polgardi',
#  'attawapiskat',
#  'cheuskiny',
#  'hvammstangi',
#  'abdanan',
#  'mar del plata',
#  'shatsk',
#  'walvis bay',
#  'talcahuano',
#  'the valley',
#  'koshki',
#  'margate',
#  'port elizabeth',
#  'punta arenas',
#  'alta floresta',
#  'tunduru',
#  'marabba',
#  'sedelnikovo',
#  'potgietersrus',
#  'rio gallegos',
#  'longyearbyen',
#  'mahebourg',
#  'toliary',
#  'dovolnoye',
#  'kobryn',
#  'husavik',
#  'sao raimundo das mangabeiras',
#  'lasa',
#  'pointe michel',
#  'saint-francois',
#  'leshukonskoye',
#  'olafsvik',
#  'praia da vitoria',
#  'salalah',
#  'marcona',
#  'qeshm',
#  'monte san pietro',
#  'keffi',
#  'nanortalik',
#  'desnogorsk',
#  'solovetskiy',
#  'upernavik',
#  'hermanus',
#  'pestravka',
#  'ilebo',
#  'mocambique',
#  'amderma',
#  'shache',
#  'lebu',
#  'totness',
#  'gardez',
#  'dikson',
#  'lubumbashi',
#  'longlac',
#  'khed brahma',
#  'hamilton',
#  'pitimbu',
#  'hithadhoo',
#  'petrolina',
#  'bageshwar',
#  'port blair',
#  'bishop auckland',
#  'adrar',
#  'road town',
#  'ilo',
#  'aksarka',
#  'henties bay',
#  'mhlume',
#  'sayyan',
#  'babra',
#  'richards bay',
#  'bathsheba',
#  'batticaloa',
#  'bilma',
#  'naustdal',
#  'maniitsoq',
#  'stornoway',
#  'grindavik',
#  'isla mujeres',
#  'mariestad',
#  'challans',
#  'novyy urengoy',
#  'havelock',
#  'mahajanga',
#  'bonthe',
#  'carballo',
#  'veinticinco de mayo',
#  'brewster',
#  'nouadhibou',
#  'nettuno',
#  'winneba',
#  'zelenogorsk',
#  'sakakah',
#  'codrington',
#  'kutum',
#  'saint-pierre',
#  'abnub',
#  'georgetown',
#  'pangody',
#  'ajka',
#  'gzhatsk',
#  'klaksvik',
#  'eufaula',
#  'san martin',
#  'praia',
#  'qaanaaq',
#  'oktyabrskiy',
#  'abatskoye',
#  'kachikau',
#  'plavsk',
#  'krasnoselkup',
#  'novodolinskiy',
#  'kurchum',
#  'leh',
#  'muros',
#  'luderitz',
#  'umm durman',
#  'torbay',
#  'bati',
#  'touros',
#  'zile',
#  'barcelona',
#  'ardistan',
#  'matay',
#  'saquena',
#  'ilulissat',
#  'saldanha',
#  'sumbe',
#  'baracoa',
#  'ourossogui',
#  'zemio',
#  'mugan',
#  'vilhena',
#  'talnakh',
#  'atasu',
#  'iqaluit',
#  'conde',
#  'zimmi',
#  'padang',
#  'wukari',
#  'geraldton',
#  'odweyne',
#  'yambio',
#  'dzhusaly',
#  'maxixe',
#  'sao gabriel da cachoeira',
#  'mahibadhoo',
#  'chapais',
#  'thiers',
#  'nizhniy baskunchak',
#  'yenagoa',
#  'nyagan',
#  'obo',
#  'coquimbo',
#  'ilave',
#  'sioux lookout',
#  'ornskoldsvik',
#  'tacuarembo',
#  'spoleto',
#  'kachiry',
#  'nalut',
#  'armacao dos buzios',
#  'laguna',
#  'vila velha',
#  'saryshagan',
#  'rudbar',
#  'bay roberts',
#  'elizabeth city',
#  'wilmington',
#  'vardo',
#  'mayor pablo lagerenza',
#  'doha',
#  'aksu',
#  'syracuse',
#  'zaraza',
#  'la gaulette',
#  'pangnirtung',
#  'dingle',
#  'darovskoy',
#  'george town',
#  'belmonte',
#  'palmira',
#  'emba',
#  'ndioum',
#  'carnarvon',
#  'velingrad',
#  'dalvik',
#  'toro',
#  'marsaxlokk',
#  'general roca',
#  'hobyo',
#  'penzance',
#  'faya',
#  'buraydah',
#  'sechura',
#  'conselheiro pena',
#  'sao filipe',
#  'timmins',
#  'glubczyce',
#  'kalemie',
#  'chitral',
#  'tarudant',
#  'muravlenko',
#  'barreirinhas',
#  'duku',
#  'kavaratti',
#  'sorland',
#  'marrakesh',
#  'goma',
#  'kidal',
#  'marsh harbour',
#  'melipilla',
#  'podgornoye',
#  'pizarro',
#  'ponta do sol',
#  'ambodifototra',
#  'westport',
#  'asyut',
#  'remedios',
#  'luanda',
#  'rincon',
#  'baghdad',
#  'pisco',
#  'dolores',
#  'ratnagiri',
#  'garmsar',
#  'tombouctou',
#  'tinjah',
#  'nisia floresta',
#  'galle',
#  'dhilwan',
#  'doka',
#  'mariental',
#  'shubarshi',
#  'chiredzi',
#  'alpena',
#  'marawi',
#  'channel-port aux basques',
#  'dapaong',
#  'kargasok',
#  'ust-tsilma',
#  'nouakchott',
#  'viligili',
#  'harper',
#  'hualmay',
#  'dolbeau',
#  'bolungarvik',
#  'taltal',
#  'tawnat',
#  'dire',
#  'passagem franca',
#  'iturama',
#  'dieppe',
#  'bosaso',
#  'beaupre',
#  'jaleswar',
#  'kamenka',
#  'beira',
#  'gornopravdinsk',
#  'tanout',
#  'ufimskiy',
#  'caravelas',
#  'roald',
#  'mana',
#  'kayerkan',
#  'hambantota',
#  'yushala',
#  'ozgon',
#  'rundu',
#  'pervomayskiy',
#  'bonavista',
#  'serov',
#  'mehamn',
#  'abrau-dyurso',
#  'qostanay',
#  'madimba',
#  'mahanoro',
#  'eyl',
#  'gardelegen',
#  'anori',
#  'santa rosa',
#  'chaplynka',
#  'durg',
#  'shelburne',
#  'sao joao da barra',
#  'jumla',
#  'abu samrah',
#  'araci',
#  'boende',
#  'qandala',
#  'kansanshi',
#  'togur',
#  'asfi',
#  'karlstad',
#  'pedernales',
#  'adygeysk',
#  'atbasar',
#  'pinega',
#  'gualeguay',
#  'iskateley',
#  'monrovia',
#  'yefira',
#  'padilla',
#  'benguela',
#  'kaoma',
#  'abonnema',
#  'thompson',
#  'panjab',
#  'north myrtle beach',
#  'zaton',
#  'chimbote',
#  'rocha',
#  'sangolqui',
#  'valparaiso',
#  'yangambi',
#  'senanga',
#  'esenyurt',
#  'paragominas',
#  'inhambane',
#  'kassala',
#  'comodoro rivadavia',
#  'arona',
#  'kasongo-lunda',
#  'sattur',
#  'polunochnoye',
#  'antalaha',
#  'goderich',
#  'malaya purga',
#  'pasni',
#  'selty',
#  'necochea',
#  'jalingo',
#  'umm kaddadah',
#  'kolyshley',
#  'zalaszentgrot',
#  'prado',
#  'mto wa mbu',
#  'virginia beach',
#  'katsiveli',
#  'guatire',
#  'chicama',
#  'inongo',
#  'camacha',
#  'gayny',
#  'caluquembe',
#  'san rafael del sur',
#  'reconquista',
#  'parabel',
#  'el cope',
#  'neyshabur',
#  'mayumba',
#  'berlevag',
#  'cayenne',
#  'suhum',
#  'thinadhoo',
#  'ituni',
#  'sistranda',
#  'harer',
#  'jablanica',
#  'manaus',
#  'forestville',
#  'ngerengere',
#  'graaff-reinet',
#  'nantucket',
#  'rawson',
#  'igarka',
#  'quepos',
#  'ormara',
#  'porto novo',
#  'talah',
#  'benidorm',
#  'el tigre',
#  'camargo',
#  'requena',
#  'akhisar',
#  'nandaime',
#  'kangaatsiaq',
#  'ferrol',
#  'libreville',
#  'ferme-neuve',
#  'biltine',
#  'ituporanga',
#  'constitucion',
#  'mastic beach',
#  'lipin bor',
#  'tortoli',
#  'taraz',
#  'trinidad',
#  'talara',
#  'zhob',
#  'chardara',
#  'lipari',
#  'luau',
#  'bauchi',
#  'erechim',
#  'penne',
#  'mezen',
#  'akhtanizovskaya',
#  'bahia blanca',
#  'saint-joseph',
#  'dutlwe',
#  'comarapa',
#  'apatou',
#  'louisbourg',
#  'seydi',
#  'itarema',
#  'nuuk',
#  'birjand',
#  'savonlinna',
#  'sinkat',
#  'vila franca do campo',
#  'halifax',
#  'ajdabiya',
#  'sinnamary',
#  'neiba',
#  'sheregesh',
#  'drjanovo',
#  'vallenar',
#  'altamira',
#  'lumeje',
#  'chechen-aul',
#  'myrtle beach',
#  'saint-ambroise',
#  'amapa',
#  'toamasina',
#  'tete',
#  'bajo baudo',
#  'salihorsk',
#  'aliman',
#  'tobermory',
#  'bayan',
#  'qaqortoq',
#  'puerto colombia',
#  'derzhavinsk',
#  'bolshoye selo',
#  'cabaiguan',
#  'sorvag',
#  'kasama',
#  'uribia',
#  'eirunepe',
#  'loughrea',
#  'matara',
#  'liverpool',
#  'huarmey',
#  'asilah',
#  'kemin',
#  'iquique',
#  'miraflores',
#  'balkanabat',
#  'el wasta',
#  'cabedelo',
#  'barcelos',
#  'panjakent',
#  'diyarb najm',
#  'valdivia',
#  'ocotal',
#  'ondangwa',
#  'parrita',
#  'tartus',
#  'axim',
#  'bousso',
#  'carutapera',
#  'tonj',
#  'havoysund',
#  'senneterre',
#  'foumban',
#  'ullapool',
#  'arkhangelsk',
#  'setermoen',
#  'straumen',
#  'bandiagara',
#  'riyadh',
#  'sandnessjoen',
#  'gat',
#  'uray',
#  'skanevik',
#  'port-cartier',
#  'mattru',
#  'awbari',
#  'menongue',
#  'mitu',
#  'bubaque',
#  'lusambo',
#  'bombay',
#  'at-bashi',
#  'santa fe',
#  'saint anthony',
#  'maloshuyka',
#  'kabare',
#  'natal',
#  'emmaus',
#  'lagoa formosa',
#  'gravdal',
#  'salinopolis',
#  'coro',
#  'lamu',
#  'samana',
#  'camapua',
#  'donegal',
#  'chama',
#  'ust-koksa',
#  'dori',
#  'ramshir',
#  'koslan',
#  'stepnoye',
#  'hidrolandia',
#  'cape coast',
#  'malanje',
#  'lakhnadon',
#  'tubuala',
#  'sao desiderio',
#  'merzifon',
#  'abancay',
#  'ambilobe',
#  'kanashevo',
#  'vangaindrano',
#  'bozdar',
#  'marfino',
#  'champa',
#  'waw',
#  'lixourion',
#  'jubayl',
#  'doctor pedro p. pena',
#  'kipini',
#  'gao',
#  'ponta delgada',
#  'sindand',
#  'tabuk',
#  'harlingen',
#  'bonanza',
#  'cernesti',
#  'bacalar',
#  'cantanhede',
#  'sivas',
#  'puerto cabezas',
#  'boa vista',
#  'scottsboro',
#  'chorozinho',
#  'panvel',
#  'san juan',
#  'karaul',
#  'wawa',
#  'acarau',
#  'mbaiki',
#  'diffa',
#  'ghanzi',
#  'fomboni',
#  'qasigiannguit',
#  'ravar',
#  'salamiyah',
#  'mbuji-mayi',
#  'atar',
#  'guayaramerin',
#  'smalininkai',
#  'kuche',
#  'pimenta bueno',
#  'illela',
#  'hollins',
#  'diego de almagro',
#  'saint-augustin',
#  'neuquen',
#  'garowe',
#  'horni benesov',
#  'durban',
#  'san pedro',
#  'bay city',
#  'chebenki',
#  'puri',
#  'saint-louis',
#  'vieques',
#  'pirganj',
#  'ostrowiec swietokrzyski',
#  'albany',
#  'olinda',
#  'akdepe',
#  'lieksa',
#  'athens',
#  'bahia honda',
#  'el alto',
#  'alekseyevskaya',
#  'jackson',
#  'abalak',
#  'waddan',
#  'aksehir',
#  'novopetrovskoye',
#  'bereznik',
#  'borovskoy',
#  'starobaltachevo',
#  'carolina',
#  'oussouye',
#  'antofagasta',
#  'vazante',
#  'black river',
#  'petropavlovskoye',
#  'martinsburg',
#  'ancud',
#  'frederikshavn',
#  'parana',
#  'mrirt',
#  'manicore',
#  'muret',
#  'kaman',
#  'san pedro de macoris',
#  'imperia',
#  'angoche',
#  'pokhara',
#  'jalu',
#  'lukulu',
#  'bengkulu',
#  'plakhtiyivka',
#  'duz',
#  'apollonia',
#  'newry',
#  'nizhnevartovsk',
#  'villanueva de la serena',
#  'zeerust',
#  'artyom',
#  'staraya mayna',
#  'sao miguel',
#  'santa maria',
#  'santa isabel do rio negro',
#  'nandurbar',
#  'ayios matthaios',
#  'carauari',
#  'bewar',
#  'bud',
#  'balkhash',
#  'cururupu',
#  'porto velho',
#  'bur gabo',
#  'paoua',
#  'pavlodar',
#  'ozinki',
#  'zuwarah',
#  'strangnas',
#  'linhares',
#  'octeville',
#  'ayapel',
#  'jeremie',
#  'ibi',
#  'karpuninskiy',
#  'tiruvottiyur',
#  'afyonkarahisar',
#  'toledo',
#  'filingue',
#  'mogadishu',
#  'marzuq',
#  'jagodina',
#  'samus',
#  'beyneu',
#  'maragogi',
#  'nizhneivkino',
#  'mamallapuram',
#  'san rafael',
#  'urucuca',
#  'sudak',
#  'kirkwall',
#  'osypenko',
#  'oswego']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?" 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city.replace(" ","+") + "&units=metric"
    print(city_url)
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
       
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        #print(city_clouds)
        city_wind = city_weather["wind"]["speed"]
        #print(city_wind)
        city_country = city_weather["sys"]["country"]
        #print(city_country)
        city_weather_desc = city_weather["weather"][0]["description"]
       
        # Append the city information into the city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ribeira+grande&units=metric
# Processing Record 1 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=souillac&units=metric
# Processing Record 2 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=surt&units=metric
# Processing Record 3 of Set 1 | surt
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=neftcala&units=metric
# Processing Record 4 of Set 1 | neftcala
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=jamestown&units=metric
# Processing Record 5 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ushuaia&units=metric
# Processing Record 6 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=arraial+do+cabo&units=metric
# Processing Record 7 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sala+consilina&units=metric
# Processing Record 8 of Set 1 | sala consilina
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=savannah+bight&units=metric
# Processing Record 9 of Set 1 | savannah bight
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=port+alfred&units=metric
# Processing Record 10 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cockburn+town&units=metric
# Processing Record 11 of Set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cidreira&units=metric
# Processing Record 12 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=narsaq&units=metric
# Processing Record 13 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=la+baule-escoublac&units=metric
# Processing Record 14 of Set 1 | la baule-escoublac
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+cristobal&units=metric
# Processing Record 15 of Set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=busselton&units=metric
# Processing Record 16 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=clyde+river&units=metric
# Processing Record 17 of Set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lerwick&units=metric
# Processing Record 18 of Set 1 | lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tanga&units=metric
# Processing Record 19 of Set 1 | tanga
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=castro&units=metric
# Processing Record 20 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tsihombe&units=metric
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cape+town&units=metric
# Processing Record 22 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=belushya+guba&units=metric
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vestmanna&units=metric
# Processing Record 24 of Set 1 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=keetmanshoop&units=metric
# Processing Record 25 of Set 1 | keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=rey+bouba&units=metric
# Processing Record 26 of Set 1 | rey bouba
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lagoa&units=metric
# Processing Record 27 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kruisfontein&units=metric
# Processing Record 28 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=santa+vitoria+do+palmar&units=metric
# Processing Record 29 of Set 1 | santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=taolanaro&units=metric
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=umzimvubu&units=metric
# Processing Record 31 of Set 1 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ginda&units=metric
# Processing Record 32 of Set 1 | ginda
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=quatre+cocos&units=metric
# Processing Record 33 of Set 1 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=horadiz&units=metric
# Processing Record 34 of Set 1 | horadiz
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kondinskoye&units=metric
# Processing Record 35 of Set 1 | kondinskoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sambava&units=metric
# Processing Record 36 of Set 1 | sambava
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=aleksandrov+gay&units=metric
# Processing Record 37 of Set 1 | aleksandrov gay
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=east+london&units=metric
# Processing Record 38 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=barentsburg&units=metric
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=rochegda&units=metric
# Processing Record 40 of Set 1 | rochegda
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tasiilaq&units=metric
# Processing Record 41 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pagman&units=metric
# Processing Record 42 of Set 1 | pagman
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=namibe&units=metric
# Processing Record 43 of Set 1 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=korla&units=metric
# Processing Record 44 of Set 1 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nokaneng&units=metric
# Processing Record 45 of Set 1 | nokaneng
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bandarbeyla&units=metric
# Processing Record 46 of Set 1 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=chuy&units=metric
# Processing Record 47 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ofaqim&units=metric
# Processing Record 48 of Set 1 | ofaqim
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cravo+norte&units=metric
# Processing Record 49 of Set 1 | cravo norte
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=narasannapeta&units=metric
# Processing Record 50 of Set 1 | narasannapeta
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=illoqqortoormiut&units=metric
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=babanka&units=metric
# Processing Record 2 of Set 2 | babanka
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=karkaralinsk&units=metric
# Processing Record 3 of Set 2 | karkaralinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ohangaron&units=metric
# Processing Record 4 of Set 2 | ohangaron
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bredasdorp&units=metric
# Processing Record 5 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=gasa&units=metric
# Processing Record 6 of Set 2 | gasa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+carlos+de+bariloche&units=metric
# Processing Record 7 of Set 2 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nelidovo&units=metric
# Processing Record 8 of Set 2 | nelidovo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=maceio&units=metric
# Processing Record 9 of Set 2 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=urucara&units=metric
# Processing Record 10 of Set 2 | urucara
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pionerskiy&units=metric
# Processing Record 11 of Set 2 | pionerskiy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=grand+gaube&units=metric
# Processing Record 12 of Set 2 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=buchanan&units=metric
# Processing Record 13 of Set 2 | buchanan
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cap+malheureux&units=metric
# Processing Record 14 of Set 2 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=azare&units=metric
# Processing Record 15 of Set 2 | azare
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lima&units=metric
# Processing Record 16 of Set 2 | lima
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mezhdurechensk&units=metric
# Processing Record 17 of Set 2 | mezhdurechensk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saint-philippe&units=metric
# Processing Record 18 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vestmannaeyjar&units=metric
# Processing Record 19 of Set 2 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=coihaique&units=metric
# Processing Record 20 of Set 2 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sur&units=metric
# Processing Record 21 of Set 2 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ostrovnoy&units=metric
# Processing Record 22 of Set 2 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=taoudenni&units=metric
# Processing Record 23 of Set 2 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=victoria&units=metric
# Processing Record 24 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=urdoma&units=metric
# Processing Record 25 of Set 2 | urdoma
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=barawe&units=metric
# Processing Record 26 of Set 2 | barawe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bambous+virieux&units=metric
# Processing Record 27 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saint+george&units=metric
# Processing Record 28 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=grand+river+south+east&units=metric
# Processing Record 29 of Set 2 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=paamiut&units=metric
# Processing Record 30 of Set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=shieli&units=metric
# Processing Record 31 of Set 2 | shieli
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+ramon+de+la+nueva+oran&units=metric
# Processing Record 32 of Set 2 | san ramon de la nueva oran
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=iralaya&units=metric
# Processing Record 33 of Set 2 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tumannyy&units=metric
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tara&units=metric
# Processing Record 35 of Set 2 | tara
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=polgardi&units=metric
# Processing Record 36 of Set 2 | polgardi
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=attawapiskat&units=metric
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cheuskiny&units=metric
# Processing Record 38 of Set 2 | cheuskiny
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=hvammstangi&units=metric
# Processing Record 39 of Set 2 | hvammstangi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=abdanan&units=metric
# Processing Record 40 of Set 2 | abdanan
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mar+del+plata&units=metric
# Processing Record 41 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=shatsk&units=metric
# Processing Record 42 of Set 2 | shatsk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=walvis+bay&units=metric
# Processing Record 43 of Set 2 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=talcahuano&units=metric
# Processing Record 44 of Set 2 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=the+valley&units=metric
# Processing Record 45 of Set 2 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=koshki&units=metric
# Processing Record 46 of Set 2 | koshki
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=margate&units=metric
# Processing Record 47 of Set 2 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=port+elizabeth&units=metric
# Processing Record 48 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=punta+arenas&units=metric
# Processing Record 49 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=alta+floresta&units=metric
# Processing Record 50 of Set 2 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tunduru&units=metric
# Processing Record 1 of Set 3 | tunduru
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=marabba&units=metric
# Processing Record 2 of Set 3 | marabba
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sedelnikovo&units=metric
# Processing Record 3 of Set 3 | sedelnikovo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=potgietersrus&units=metric
# Processing Record 4 of Set 3 | potgietersrus
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=rio+gallegos&units=metric
# Processing Record 5 of Set 3 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=longyearbyen&units=metric
# Processing Record 6 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mahebourg&units=metric
# Processing Record 7 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=toliary&units=metric
# Processing Record 8 of Set 3 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=dovolnoye&units=metric
# Processing Record 9 of Set 3 | dovolnoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kobryn&units=metric
# Processing Record 10 of Set 3 | kobryn
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=husavik&units=metric
# Processing Record 11 of Set 3 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sao+raimundo+das+mangabeiras&units=metric
# Processing Record 12 of Set 3 | sao raimundo das mangabeiras
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lasa&units=metric
# Processing Record 13 of Set 3 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pointe+michel&units=metric
# Processing Record 14 of Set 3 | pointe michel
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saint-francois&units=metric
# Processing Record 15 of Set 3 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=leshukonskoye&units=metric
# Processing Record 16 of Set 3 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=olafsvik&units=metric
# Processing Record 17 of Set 3 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=praia+da+vitoria&units=metric
# Processing Record 18 of Set 3 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=salalah&units=metric
# Processing Record 19 of Set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=marcona&units=metric
# Processing Record 20 of Set 3 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=qeshm&units=metric
# Processing Record 21 of Set 3 | qeshm
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=monte+san+pietro&units=metric
# Processing Record 22 of Set 3 | monte san pietro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=keffi&units=metric
# Processing Record 23 of Set 3 | keffi
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nanortalik&units=metric
# Processing Record 24 of Set 3 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=desnogorsk&units=metric
# Processing Record 25 of Set 3 | desnogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=solovetskiy&units=metric
# Processing Record 26 of Set 3 | solovetskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=upernavik&units=metric
# Processing Record 27 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=hermanus&units=metric
# Processing Record 28 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pestravka&units=metric
# Processing Record 29 of Set 3 | pestravka
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ilebo&units=metric
# Processing Record 30 of Set 3 | ilebo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mocambique&units=metric
# Processing Record 31 of Set 3 | mocambique
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=amderma&units=metric
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=shache&units=metric
# Processing Record 33 of Set 3 | shache
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lebu&units=metric
# Processing Record 34 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=totness&units=metric
# Processing Record 35 of Set 3 | totness
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=gardez&units=metric
# Processing Record 36 of Set 3 | gardez
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=dikson&units=metric
# Processing Record 37 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lubumbashi&units=metric
# Processing Record 38 of Set 3 | lubumbashi
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=longlac&units=metric
# Processing Record 39 of Set 3 | longlac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=khed+brahma&units=metric
# Processing Record 40 of Set 3 | khed brahma
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=hamilton&units=metric
# Processing Record 41 of Set 3 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pitimbu&units=metric
# Processing Record 42 of Set 3 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=hithadhoo&units=metric
# Processing Record 43 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=petrolina&units=metric
# Processing Record 44 of Set 3 | petrolina
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bageshwar&units=metric
# Processing Record 45 of Set 3 | bageshwar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=port+blair&units=metric
# Processing Record 46 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bishop+auckland&units=metric
# Processing Record 47 of Set 3 | bishop auckland
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=adrar&units=metric
# Processing Record 48 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=road+town&units=metric
# Processing Record 49 of Set 3 | road town
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ilo&units=metric
# Processing Record 50 of Set 3 | ilo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=aksarka&units=metric
# Processing Record 1 of Set 4 | aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=henties+bay&units=metric
# Processing Record 2 of Set 4 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mhlume&units=metric
# Processing Record 3 of Set 4 | mhlume
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sayyan&units=metric
# Processing Record 4 of Set 4 | sayyan
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=babra&units=metric
# Processing Record 5 of Set 4 | babra
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=richards+bay&units=metric
# Processing Record 6 of Set 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bathsheba&units=metric
# Processing Record 7 of Set 4 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=batticaloa&units=metric
# Processing Record 8 of Set 4 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bilma&units=metric
# Processing Record 9 of Set 4 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=naustdal&units=metric
# Processing Record 10 of Set 4 | naustdal
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=maniitsoq&units=metric
# Processing Record 11 of Set 4 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=stornoway&units=metric
# Processing Record 12 of Set 4 | stornoway
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=grindavik&units=metric
# Processing Record 13 of Set 4 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=isla+mujeres&units=metric
# Processing Record 14 of Set 4 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mariestad&units=metric
# Processing Record 15 of Set 4 | mariestad
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=challans&units=metric
# Processing Record 16 of Set 4 | challans
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=novyy+urengoy&units=metric
# Processing Record 17 of Set 4 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=havelock&units=metric
# Processing Record 18 of Set 4 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mahajanga&units=metric
# Processing Record 19 of Set 4 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bonthe&units=metric
# Processing Record 20 of Set 4 | bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=carballo&units=metric
# Processing Record 21 of Set 4 | carballo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=veinticinco+de+mayo&units=metric
# Processing Record 22 of Set 4 | veinticinco de mayo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=brewster&units=metric
# Processing Record 23 of Set 4 | brewster
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nouadhibou&units=metric
# Processing Record 24 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nettuno&units=metric
# Processing Record 25 of Set 4 | nettuno
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=winneba&units=metric
# Processing Record 26 of Set 4 | winneba
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zelenogorsk&units=metric
# Processing Record 27 of Set 4 | zelenogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sakakah&units=metric
# Processing Record 28 of Set 4 | sakakah
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=codrington&units=metric
# Processing Record 29 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kutum&units=metric
# Processing Record 30 of Set 4 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saint-pierre&units=metric
# Processing Record 31 of Set 4 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=abnub&units=metric
# Processing Record 32 of Set 4 | abnub
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=georgetown&units=metric
# Processing Record 33 of Set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pangody&units=metric
# Processing Record 34 of Set 4 | pangody
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ajka&units=metric
# Processing Record 35 of Set 4 | ajka
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=gzhatsk&units=metric
# Processing Record 36 of Set 4 | gzhatsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=klaksvik&units=metric
# Processing Record 37 of Set 4 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=eufaula&units=metric
# Processing Record 38 of Set 4 | eufaula
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+martin&units=metric
# Processing Record 39 of Set 4 | san martin
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=praia&units=metric
# Processing Record 40 of Set 4 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=qaanaaq&units=metric
# Processing Record 41 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=oktyabrskiy&units=metric
# Processing Record 42 of Set 4 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=abatskoye&units=metric
# Processing Record 43 of Set 4 | abatskoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kachikau&units=metric
# Processing Record 44 of Set 4 | kachikau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=plavsk&units=metric
# Processing Record 45 of Set 4 | plavsk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=krasnoselkup&units=metric
# Processing Record 46 of Set 4 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=novodolinskiy&units=metric
# Processing Record 47 of Set 4 | novodolinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kurchum&units=metric
# Processing Record 48 of Set 4 | kurchum
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=leh&units=metric
# Processing Record 49 of Set 4 | leh
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=muros&units=metric
# Processing Record 50 of Set 4 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=luderitz&units=metric
# Processing Record 1 of Set 5 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=umm+durman&units=metric
# Processing Record 2 of Set 5 | umm durman
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=torbay&units=metric
# Processing Record 3 of Set 5 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bati&units=metric
# Processing Record 4 of Set 5 | bati
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=touros&units=metric
# Processing Record 5 of Set 5 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zile&units=metric
# Processing Record 6 of Set 5 | zile
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=barcelona&units=metric
# Processing Record 7 of Set 5 | barcelona
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ardistan&units=metric
# Processing Record 8 of Set 5 | ardistan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=matay&units=metric
# Processing Record 9 of Set 5 | matay
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saquena&units=metric
# Processing Record 10 of Set 5 | saquena
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ilulissat&units=metric
# Processing Record 11 of Set 5 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saldanha&units=metric
# Processing Record 12 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sumbe&units=metric
# Processing Record 13 of Set 5 | sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=baracoa&units=metric
# Processing Record 14 of Set 5 | baracoa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ourossogui&units=metric
# Processing Record 15 of Set 5 | ourossogui
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zemio&units=metric
# Processing Record 16 of Set 5 | zemio
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mugan&units=metric
# Processing Record 17 of Set 5 | mugan
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vilhena&units=metric
# Processing Record 18 of Set 5 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=talnakh&units=metric
# Processing Record 19 of Set 5 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=atasu&units=metric
# Processing Record 20 of Set 5 | atasu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=iqaluit&units=metric
# Processing Record 21 of Set 5 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=conde&units=metric
# Processing Record 22 of Set 5 | conde
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zimmi&units=metric
# Processing Record 23 of Set 5 | zimmi
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=padang&units=metric
# Processing Record 24 of Set 5 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=wukari&units=metric
# Processing Record 25 of Set 5 | wukari
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=geraldton&units=metric
# Processing Record 26 of Set 5 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=odweyne&units=metric
# Processing Record 27 of Set 5 | odweyne
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=yambio&units=metric
# Processing Record 28 of Set 5 | yambio
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=dzhusaly&units=metric
# Processing Record 29 of Set 5 | dzhusaly
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=maxixe&units=metric
# Processing Record 30 of Set 5 | maxixe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sao+gabriel+da+cachoeira&units=metric
# Processing Record 31 of Set 5 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mahibadhoo&units=metric
# Processing Record 32 of Set 5 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=chapais&units=metric
# Processing Record 33 of Set 5 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=thiers&units=metric
# Processing Record 34 of Set 5 | thiers
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nizhniy+baskunchak&units=metric
# Processing Record 35 of Set 5 | nizhniy baskunchak
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=yenagoa&units=metric
# Processing Record 36 of Set 5 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nyagan&units=metric
# Processing Record 37 of Set 5 | nyagan
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=obo&units=metric
# Processing Record 38 of Set 5 | obo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=coquimbo&units=metric
# Processing Record 39 of Set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ilave&units=metric
# Processing Record 40 of Set 5 | ilave
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sioux+lookout&units=metric
# Processing Record 41 of Set 5 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ornskoldsvik&units=metric
# Processing Record 42 of Set 5 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tacuarembo&units=metric
# Processing Record 43 of Set 5 | tacuarembo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=spoleto&units=metric
# Processing Record 44 of Set 5 | spoleto
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kachiry&units=metric
# Processing Record 45 of Set 5 | kachiry
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nalut&units=metric
# Processing Record 46 of Set 5 | nalut
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=armacao+dos+buzios&units=metric
# Processing Record 47 of Set 5 | armacao dos buzios
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=laguna&units=metric
# Processing Record 48 of Set 5 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vila+velha&units=metric
# Processing Record 49 of Set 5 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saryshagan&units=metric
# Processing Record 50 of Set 5 | saryshagan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=rudbar&units=metric
# Processing Record 1 of Set 6 | rudbar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bay+roberts&units=metric
# Processing Record 2 of Set 6 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=elizabeth+city&units=metric
# Processing Record 3 of Set 6 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=wilmington&units=metric
# Processing Record 4 of Set 6 | wilmington
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vardo&units=metric
# Processing Record 5 of Set 6 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mayor+pablo+lagerenza&units=metric
# Processing Record 6 of Set 6 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=doha&units=metric
# Processing Record 7 of Set 6 | doha
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=aksu&units=metric
# Processing Record 8 of Set 6 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=syracuse&units=metric
# Processing Record 9 of Set 6 | syracuse
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zaraza&units=metric
# Processing Record 10 of Set 6 | zaraza
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=la+gaulette&units=metric
# Processing Record 11 of Set 6 | la gaulette
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pangnirtung&units=metric
# Processing Record 12 of Set 6 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=dingle&units=metric
# Processing Record 13 of Set 6 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=darovskoy&units=metric
# Processing Record 14 of Set 6 | darovskoy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=george+town&units=metric
# Processing Record 15 of Set 6 | george town
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=belmonte&units=metric
# Processing Record 16 of Set 6 | belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=palmira&units=metric
# Processing Record 17 of Set 6 | palmira
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=emba&units=metric
# Processing Record 18 of Set 6 | emba
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ndioum&units=metric
# Processing Record 19 of Set 6 | ndioum
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=carnarvon&units=metric
# Processing Record 20 of Set 6 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=velingrad&units=metric
# Processing Record 21 of Set 6 | velingrad
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=dalvik&units=metric
# Processing Record 22 of Set 6 | dalvik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=toro&units=metric
# Processing Record 23 of Set 6 | toro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=marsaxlokk&units=metric
# Processing Record 24 of Set 6 | marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=general+roca&units=metric
# Processing Record 25 of Set 6 | general roca
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=hobyo&units=metric
# Processing Record 26 of Set 6 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=penzance&units=metric
# Processing Record 27 of Set 6 | penzance
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=faya&units=metric
# Processing Record 28 of Set 6 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=buraydah&units=metric
# Processing Record 29 of Set 6 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sechura&units=metric
# Processing Record 30 of Set 6 | sechura
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=conselheiro+pena&units=metric
# Processing Record 31 of Set 6 | conselheiro pena
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sao+filipe&units=metric
# Processing Record 32 of Set 6 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=timmins&units=metric
# Processing Record 33 of Set 6 | timmins
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=glubczyce&units=metric
# Processing Record 34 of Set 6 | glubczyce
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kalemie&units=metric
# Processing Record 35 of Set 6 | kalemie
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=chitral&units=metric
# Processing Record 36 of Set 6 | chitral
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tarudant&units=metric
# Processing Record 37 of Set 6 | tarudant
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=muravlenko&units=metric
# Processing Record 38 of Set 6 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=barreirinhas&units=metric
# Processing Record 39 of Set 6 | barreirinhas
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=duku&units=metric
# Processing Record 40 of Set 6 | duku
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kavaratti&units=metric
# Processing Record 41 of Set 6 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sorland&units=metric
# Processing Record 42 of Set 6 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=marrakesh&units=metric
# Processing Record 43 of Set 6 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=goma&units=metric
# Processing Record 44 of Set 6 | goma
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kidal&units=metric
# Processing Record 45 of Set 6 | kidal
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=marsh+harbour&units=metric
# Processing Record 46 of Set 6 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=melipilla&units=metric
# Processing Record 47 of Set 6 | melipilla
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=podgornoye&units=metric
# Processing Record 48 of Set 6 | podgornoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pizarro&units=metric
# Processing Record 49 of Set 6 | pizarro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ponta+do+sol&units=metric
# Processing Record 50 of Set 6 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ambodifototra&units=metric
# Processing Record 1 of Set 7 | ambodifototra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=westport&units=metric
# Processing Record 2 of Set 7 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=asyut&units=metric
# Processing Record 3 of Set 7 | asyut
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=remedios&units=metric
# Processing Record 4 of Set 7 | remedios
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=luanda&units=metric
# Processing Record 5 of Set 7 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=rincon&units=metric
# Processing Record 6 of Set 7 | rincon
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=baghdad&units=metric
# Processing Record 7 of Set 7 | baghdad
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pisco&units=metric
# Processing Record 8 of Set 7 | pisco
# ...
# Processing Record 42 of Set 13 | illela
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=hollins&units=metric
# Processing Record 43 of Set 13 | hollins
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=diego+de+almagro&units=metric
# Processing Record 44 of Set 13 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saint-augustin&units=metric
# Processing Record 45 of Set 13 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=neuquen&units=metric
# Processing Record 46 of Set 13 | neuquen
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=garowe&units=metric
# Processing Record 47 of Set 13 | garowe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=horni+benesov&units=metric
# Processing Record 48 of Set 13 | horni benesov
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=durban&units=metric
# Processing Record 49 of Set 13 | durban
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+pedro&units=metric
# Processing Record 50 of Set 13 | san pedro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bay+city&units=metric
# Processing Record 1 of Set 14 | bay city
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=chebenki&units=metric
# Processing Record 2 of Set 14 | chebenki
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=puri&units=metric
# Processing Record 3 of Set 14 | puri
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=saint-louis&units=metric
# Processing Record 4 of Set 14 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vieques&units=metric
# Processing Record 5 of Set 14 | vieques
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pirganj&units=metric
# Processing Record 6 of Set 14 | pirganj
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ostrowiec+swietokrzyski&units=metric
# Processing Record 7 of Set 14 | ostrowiec swietokrzyski
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=albany&units=metric
# Processing Record 8 of Set 14 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=olinda&units=metric
# Processing Record 9 of Set 14 | olinda
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=akdepe&units=metric
# Processing Record 10 of Set 14 | akdepe
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lieksa&units=metric
# Processing Record 11 of Set 14 | lieksa
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=athens&units=metric
# Processing Record 12 of Set 14 | athens
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bahia+honda&units=metric
# Processing Record 13 of Set 14 | bahia honda
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=el+alto&units=metric
# Processing Record 14 of Set 14 | el alto
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=alekseyevskaya&units=metric
# Processing Record 15 of Set 14 | alekseyevskaya
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=jackson&units=metric
# Processing Record 16 of Set 14 | jackson
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=abalak&units=metric
# Processing Record 17 of Set 14 | abalak
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=waddan&units=metric
# Processing Record 18 of Set 14 | waddan
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=aksehir&units=metric
# Processing Record 19 of Set 14 | aksehir
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=novopetrovskoye&units=metric
# Processing Record 20 of Set 14 | novopetrovskoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bereznik&units=metric
# Processing Record 21 of Set 14 | bereznik
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=borovskoy&units=metric
# Processing Record 22 of Set 14 | borovskoy
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=starobaltachevo&units=metric
# Processing Record 23 of Set 14 | starobaltachevo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=carolina&units=metric
# Processing Record 24 of Set 14 | carolina
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=oussouye&units=metric
# Processing Record 25 of Set 14 | oussouye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=antofagasta&units=metric
# Processing Record 26 of Set 14 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=vazante&units=metric
# Processing Record 27 of Set 14 | vazante
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=black+river&units=metric
# Processing Record 28 of Set 14 | black river
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=petropavlovskoye&units=metric
# Processing Record 29 of Set 14 | petropavlovskoye
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=martinsburg&units=metric
# Processing Record 30 of Set 14 | martinsburg
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ancud&units=metric
# Processing Record 31 of Set 14 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=frederikshavn&units=metric
# Processing Record 32 of Set 14 | frederikshavn
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=parana&units=metric
# Processing Record 33 of Set 14 | parana
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mrirt&units=metric
# Processing Record 34 of Set 14 | mrirt
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=manicore&units=metric
# Processing Record 35 of Set 14 | manicore
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=muret&units=metric
# Processing Record 36 of Set 14 | muret
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kaman&units=metric
# Processing Record 37 of Set 14 | kaman
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+pedro+de+macoris&units=metric
# Processing Record 38 of Set 14 | san pedro de macoris
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=imperia&units=metric
# Processing Record 39 of Set 14 | imperia
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=angoche&units=metric
# Processing Record 40 of Set 14 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pokhara&units=metric
# Processing Record 41 of Set 14 | pokhara
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=jalu&units=metric
# Processing Record 42 of Set 14 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=lukulu&units=metric
# Processing Record 43 of Set 14 | lukulu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bengkulu&units=metric
# Processing Record 44 of Set 14 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=plakhtiyivka&units=metric
# Processing Record 45 of Set 14 | plakhtiyivka
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=duz&units=metric
# Processing Record 46 of Set 14 | duz
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=apollonia&units=metric
# Processing Record 47 of Set 14 | apollonia
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=newry&units=metric
# Processing Record 48 of Set 14 | newry
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nizhnevartovsk&units=metric
# Processing Record 49 of Set 14 | nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=villanueva+de+la+serena&units=metric
# Processing Record 50 of Set 14 | villanueva de la serena
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zeerust&units=metric
# Processing Record 1 of Set 15 | zeerust
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=artyom&units=metric
# Processing Record 2 of Set 15 | artyom
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=staraya+mayna&units=metric
# Processing Record 3 of Set 15 | staraya mayna
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sao+miguel&units=metric
# Processing Record 4 of Set 15 | sao miguel
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=santa+maria&units=metric
# Processing Record 5 of Set 15 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=santa+isabel+do+rio+negro&units=metric
# Processing Record 6 of Set 15 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nandurbar&units=metric
# Processing Record 7 of Set 15 | nandurbar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ayios+matthaios&units=metric
# Processing Record 8 of Set 15 | ayios matthaios
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=carauari&units=metric
# Processing Record 9 of Set 15 | carauari
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bewar&units=metric
# Processing Record 10 of Set 15 | bewar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bud&units=metric
# Processing Record 11 of Set 15 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=balkhash&units=metric
# Processing Record 12 of Set 15 | balkhash
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=cururupu&units=metric
# Processing Record 13 of Set 15 | cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=porto+velho&units=metric
# Processing Record 14 of Set 15 | porto velho
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=bur+gabo&units=metric
# Processing Record 15 of Set 15 | bur gabo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=paoua&units=metric
# Processing Record 16 of Set 15 | paoua
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=pavlodar&units=metric
# Processing Record 17 of Set 15 | pavlodar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ozinki&units=metric
# Processing Record 18 of Set 15 | ozinki
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=zuwarah&units=metric
# Processing Record 19 of Set 15 | zuwarah
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=strangnas&units=metric
# Processing Record 20 of Set 15 | strangnas
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=linhares&units=metric
# Processing Record 21 of Set 15 | linhares
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=octeville&units=metric
# Processing Record 22 of Set 15 | octeville
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ayapel&units=metric
# Processing Record 23 of Set 15 | ayapel
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=jeremie&units=metric
# Processing Record 24 of Set 15 | jeremie
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=ibi&units=metric
# Processing Record 25 of Set 15 | ibi
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=karpuninskiy&units=metric
# Processing Record 26 of Set 15 | karpuninskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=tiruvottiyur&units=metric
# Processing Record 27 of Set 15 | tiruvottiyur
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=afyonkarahisar&units=metric
# Processing Record 28 of Set 15 | afyonkarahisar
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=toledo&units=metric
# Processing Record 29 of Set 15 | toledo
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=filingue&units=metric
# Processing Record 30 of Set 15 | filingue
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mogadishu&units=metric
# Processing Record 31 of Set 15 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=marzuq&units=metric
# Processing Record 32 of Set 15 | marzuq
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=jagodina&units=metric
# Processing Record 33 of Set 15 | jagodina
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=samus&units=metric
# Processing Record 34 of Set 15 | samus
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=beyneu&units=metric
# Processing Record 35 of Set 15 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=maragogi&units=metric
# Processing Record 36 of Set 15 | maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=nizhneivkino&units=metric
# Processing Record 37 of Set 15 | nizhneivkino
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=mamallapuram&units=metric
# Processing Record 38 of Set 15 | mamallapuram
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=san+rafael&units=metric
# Processing Record 39 of Set 15 | san rafael
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=urucuca&units=metric
# Processing Record 40 of Set 15 | urucuca
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=sudak&units=metric
# Processing Record 41 of Set 15 | sudak
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=kirkwall&units=metric
# Processing Record 42 of Set 15 | kirkwall
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=osypenko&units=metric
# Processing Record 43 of Set 15 | osypenko
# http://api.openweathermap.org/data/2.5/weather?appid=d60baafc02218b8b1d2f8b5596efd5df&q=oswego&units=metric
# Processing Record 44 of Set 15 | oswego
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   ribeira grande  38.5167 -28.7000     21.84        83          97
# 1         souillac -20.5167  57.5167     22.21        78          75
# 2             surt  31.2089  16.5887     23.31        67           1
# 3         neftcala  39.3742  49.2472     22.19        69           1
# 4        jamestown  42.0970 -79.2353     10.95        71          27
# 5          ushuaia -54.8000 -68.3000      3.81        87         100
# 6  arraial do cabo -22.9661 -42.0278     20.50        85         100
# 7   sala consilina  40.3912  15.5989     11.90        61          99
# 8   savannah bight  16.4500 -85.8500     26.97        77         100
# 9      port alfred -33.5906  26.8910     15.10        93          62
#
#    Wind Speed Country Current Description
# 0        2.49      PT     overcast clouds
# 1        5.66      MU       broken clouds
# 2        4.27      LY           clear sky
# 3        9.43      AZ           clear sky
# 4        0.80      US    scattered clouds
# 5        8.23      AR          light rain
# 6        5.28      BR     overcast clouds
# 7        1.44      IT     overcast clouds
# 8        3.18      HN     overcast clouds
# 9        1.79      ZA       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
new_city_df = city_data_df[new_column_order]

# Display sample data
new_city_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   ribeira grande      PT  38.5167 -28.7000     21.84        83          97
# 1         souillac      MU -20.5167  57.5167     22.21        78          75
# 2             surt      LY  31.2089  16.5887     23.31        67           1
# 3         neftcala      AZ  39.3742  49.2472     22.19        69           1
# 4        jamestown      US  42.0970 -79.2353     10.95        71          27
# 5          ushuaia      AR -54.8000 -68.3000      3.81        87         100
# 6  arraial do cabo      BR -22.9661 -42.0278     20.50        85         100
# 7   sala consilina      IT  40.3912  15.5989     11.90        61          99
# 8   savannah bight      HN  16.4500 -85.8500     26.97        77         100
# 9      port alfred      ZA -33.5906  26.8910     15.10        93          62
#
#    Wind Speed Current Description
# 0        2.49     overcast clouds
# 1        5.66       broken clouds
# 2        4.27           clear sky
# 3        9.43           clear sky
# 4        0.80    scattered clouds
# 5        8.23          light rain
# 6        5.28     overcast clouds
# 7        1.44     overcast clouds
# 8        3.18     overcast clouds
# 9        1.79       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_city_df.to_csv(output_data_file, index_label="City_ID")
